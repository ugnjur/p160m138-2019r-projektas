# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pathlib

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
path_bank_df = pathlib.Path("../data/raw/bank-full.csv")

# %%
bank_df = pd.read_csv(path_bank_df, delimiter=";")

# %%
bank_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
bank_df.describe(include="all").T
# Out:
#            count unique          top   freq      mean      std   min  25%  \
# age        45211    NaN          NaN    NaN   40.9362  10.6188    18   33
# job        45211     12  blue-collar   9732       NaN      NaN   NaN  NaN
# marital    45211      3      married  27214       NaN      NaN   NaN  NaN
# education  45211      4    secondary  23202       NaN      NaN   NaN  NaN
# default    45211      2           no  44396       NaN      NaN   NaN  NaN
# balance    45211    NaN          NaN    NaN   1362.27  3044.77 -8019   72
# housing    45211      2          yes  25130       NaN      NaN   NaN  NaN
# loan       45211      2           no  37967       NaN      NaN   NaN  NaN
# contact    45211      3     cellular  29285       NaN      NaN   NaN  NaN
# day        45211    NaN          NaN    NaN   15.8064  8.32248     1    8
# month      45211     12          may  13766       NaN      NaN   NaN  NaN
# duration   45211    NaN          NaN    NaN   258.163  257.528     0  103
# campaign   45211    NaN          NaN    NaN   2.76384  3.09802     1    1
# pdays      45211    NaN          NaN    NaN   40.1978  100.129    -1   -1
# previous   45211    NaN          NaN    NaN  0.580323  2.30344     0    0
# poutcome   45211      4      unknown  36959       NaN      NaN   NaN  NaN
# y          45211      2           no  39922       NaN      NaN   NaN  NaN
#
#            50%   75%     max
# age         39    48      95
# job        NaN   NaN     NaN
# marital    NaN   NaN     NaN
# education  NaN   NaN     NaN
# default    NaN   NaN     NaN
# balance    448  1428  102127
# housing    NaN   NaN     NaN
# loan       NaN   NaN     NaN
# contact    NaN   NaN     NaN
# day         16    21      31
# month      NaN   NaN     NaN
# duration   180   319    4918
# campaign     2     3      63
# pdays       -1    -1     871
# previous     0     0     275
# poutcome   NaN   NaN     NaN
# y          NaN   NaN     NaN

# %%
bank_df.count()
# Out:
# age          45211
# job          45211
# marital      45211
# education    45211
# default      45211
# balance      45211
# housing      45211
# loan         45211
# contact      45211
# day          45211
# month        45211
# duration     45211
# campaign     45211
# pdays        45211
# previous     45211
# poutcome     45211
# y            45211
# dtype: int64

# %%
bank_df.describe(include="object").T
# Out:
#            count unique          top   freq
# job        45211     12  blue-collar   9732
# marital    45211      3      married  27214
# education  45211      4    secondary  23202
# default    45211      2           no  44396
# housing    45211      2          yes  25130
# loan       45211      2           no  37967
# contact    45211      3     cellular  29285
# month      45211     12          may  13766
# poutcome   45211      4      unknown  36959
# y          45211      2           no  39922

# %%
bank_df.dropna().count()
# Out:
# age          45211
# job          45211
# marital      45211
# education    45211
# default      45211
# balance      45211
# housing      45211
# loan         45211
# contact      45211
# day          45211
# month        45211
# duration     45211
# campaign     45211
# pdays        45211
# previous     45211
# poutcome     45211
# y            45211
# dtype: int64

# %% [markdown]
# No missing values in the dataset.

# %%
le_y = LabelEncoder()

# %%
bank_df["target"] = le_y.fit_transform(bank_df["y"])

# %%
bank_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
bank_df["target"].describe()
# Out:
# count    45211.000000
# mean         0.116985
# std          0.321406
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: target, dtype: float64

# %%
bank_data_df = bank_df.drop('y', axis=1)

# %%
bank_data_df.shape
# Out:
# (45211, 17)

# %%
bank_df.shape
# Out:
# (45211, 18)

# %%
set(bank_df.columns).difference(bank_data_df.columns)
# Out:
# {'y'}

# %%
X = bank_data_df.drop('target', axis=1)
y = bank_data_df['target']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
seed = 111

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=seed, stratify=y)

# %%
y_train.head()
# Out:
# 34369    0
# 14137    0
# 9253     0
# 8514     0
# 3297     0
# Name: target, dtype: int64

# %%
np.mean(y_train)
# Out:
# 0.1169949777511775

# %%
np.mean(y_test)
# Out:
# 0.11699657193409267

# %%
df_train = pd.concat([X_train, pd.DataFrame({"target": y_train})], axis=1)

# %%
df_train.head()
# Out:
#        age          job   marital  education default  balance housing loan  \
# 38202   35  blue-collar  divorced  secondary      no      286     yes   no
# 37818   46  blue-collar   married  secondary      no      312     yes   no
# 8040    35    housemaid    single   tertiary      no      608     yes  yes
# 31081   42   unemployed    single    unknown      no     3274     yes   no
# 7386    29      student    single  secondary      no     1093     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 38202  cellular   15   may       158         1    365         4    other
# 37818  cellular   14   may        20         2     -1         0  unknown
# 8040    unknown    2   jun       227         1     -1         0  unknown
# 31081  cellular   16   feb       137         1     -1         0  unknown
# 7386    unknown   29   may       368         2     -1         0  unknown
#
#        target
# 38202       0
# 37818       0
# 8040        0
# 31081       0
# 7386        0

# %%
df_test = pd.concat([X_test, pd.DataFrame({"target": y_test})], axis=1)

# %%
df_train.shape
# Out:
# (36168, 17)

# %%
df_test.shape
# Out:
# (9043, 17)

# %%
df_train.to_csv(pathlib.Path("../data/interim/bank_train.csv"), index=False)
df_test.to_csv(pathlib.Path("../data/interim/bank_test.csv"), index=False)

# %%
import plotnine as gg
import numpy as np

# %%
for col in bank_df.columns:
    path = "../reports/figures/" + col + ".png"
    hist = gg.ggplot(bank_df, gg.aes(x=col)) + gg.geom_histogram()
    #print(age_hist + gg.theme_bw())
    hist.save(path)
# Out:
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/age.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 92'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/job.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 33'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/marital.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 36'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/education.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 54'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/default.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/balance.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 1447'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/housing.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 18'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/loan.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/contact.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 18'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/day.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 42'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/month.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 40'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/duration.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 406'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/campaign.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 553'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/pdays.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/previous.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/poutcome.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/y.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/target.png.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))

# %%
print(bank_df.dtypes)
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
age_hist = gg.ggplot(bank_df, gg.aes(x="job")) + gg.geom_histogram()
print(age_hist + gg.theme_bw())
age_hist.save("../reports/figures/z_graph.png", width=20, height=6)
# Out:
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 33'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (-9223363309342975691)>
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:708: UserWarning: Saving 20 x 6 in image.
#   from_inches(height, units), units))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/ggplot.py:709: UserWarning: Filename: ../reports/figures/z_graph.png
#   warn('Filename: {}'.format(filename))
# /home/majo/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 33'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
